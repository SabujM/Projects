# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings ("ignore")

# %%
data=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/Skyserver.csv", index_col="objid")

# %%
data.head()
# Out:
#                       ra       dec         u         g         r         i  \
# objid
# 1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#                      z  run  rerun  camcol  field     specobjid   class  \
# objid
# 1.237650e+18  15.22531  752    301       4    267  3.722360e+18    STAR
# 1.237650e+18  16.39150  752    301       4    267  3.638140e+17    STAR
# 1.237650e+18  16.80125  752    301       4    268  3.232740e+17  GALAXY
# 1.237650e+18  15.90438  752    301       4    269  3.722370e+18    STAR
# 1.237650e+18  16.61326  752    301       4    269  3.722370e+18    STAR
#
#               redshift  plate    mjd  fiberid
# objid
# ...

# %%
data.dtypes
data.info()
data.describe(include="object")
data.describe()

# %%
data.isnull().sum()
# Out:
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.countplot(data["class"])
plt.xlabel("Class")
plt.ylabel("No. of cases")
plt.show()

# %%
data.columns
# Out:
# Index(['ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol', 'field',
#        'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
data.groupby("class")["ra"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="ra", data=data)
plt.show()

# %%
data.groupby("class")["dec"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="dec", data=data)
plt.show()

# %%
data.groupby("class")["u"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="u", data=data)
plt.show()

# %%
data.groupby("class")["run"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="run", data=data)
plt.show()

# %%
data.groupby("class")["camcol"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="camcol", data=data)
plt.show()

# %%
data.groupby("class")["field"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="field", data=data)
plt.show()

# %%
data.groupby("class")["specobjid"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="specobjid", data=data)
plt.show()

# %%
data.groupby("class")["redshift"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="redshift", data=data)
plt.show()

# %%
data.groupby("class")["plate"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="plate", data=data)
plt.show()

# %%
data.groupby("class")["mjd"].aggregate(["mean", max, min, "count", "std"])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="mjd", data=data)
plt.show()

# %%
data.groupby("class")["fiberid"].aggregate(["mean", max, min, "count", "std"])
# Out:
#               mean   max  min  count         std
# class
# GALAXY  340.108844   994    1   4998  186.852622
# QSO     381.558824   980    5    850  211.082659
# STAR    362.838391  1000    1   4152  225.632919

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="class", y="fiberid", data=data)
plt.show()

# %%
scatter_matrix(data, figsize=(16.5,7.5))
plt.show()

# %%
corrmat=data.corr()

# %%
plt.figure(figsize=(12,18))
m=np.ones_like(corrmat)
m[np.tril_indices_from(m)]=0
sns.heatmap(corrmat, annot=True, cmap="Accent", mask=m)
# Out:
# <AxesSubplot:>

# %%
print("Observation: from the scatterplots of the dataset and correlation matrix, we can say, all variables are positvely corelated to the dependent variable 'class' except 'field', among all the variables 'camcol'-Camera column has higher correlation value with 'class' which is .54 .After 'camcol', 'specobjid' & 'plate' have more impact than other variables.")
# Out:
# Observation: from the scatterplots of the dataset and correlation matrix, we can say, all variables are positvely corelated to the dependent variable 'class' except 'field', among all the variables 'camcol'-Camera column has higher correlation value with 'class' which is .54 .After 'camcol', 'specobjid' & 'plate' have more impact than other variables.

# %%
data.drop(columns=["rerun", "i", "z"], inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(data["class"])
data["class"]=le.fit_transform(data["class"])

# %%
#to handle the outliers
from scipy.stats import zscore
z=abs(zscore(data))
data_mod=data[(z<3).all(axis=1)]

# %%
data.shape, data_mod.shape
# Out:
# ((10000, 14), (8724, 14))

# %%
X=data.drop(columns="class")
y=data["class"]

# %%
#to handle the skewness
X.skew()
import numpy as np
for col in X.columns:
    if X[col].skew()>.55:
        X[col]=np.log1p(X[col])

# %%
X.skew()
# Out:
# ra          -1.227350
# dec          0.152301
# u           -1.219795
# g           -0.536293
# r           -0.021673
# run          0.412555
# camcol      -0.100220
# field        0.249795
# specobjid    0.696181
# redshift     3.513844
# plate        0.696680
# mjd          1.011097
# fiberid      0.308053
# dtype: float64

# %%
X.drop(columns="dec", inplace=True)

# %%
#to handle multi collinearity of predictors
from statsmodels.stats.outliers_influence import variance_inflation_factor as vifs
vif=pd.DataFrame()
vif["Features"]=X.columns
vif["VIF"]=[vifs(X.values,i) for i in range(X.shape[1])]
vif
# Out:
#      Features           VIF
# 0          ra  2.613431e+01
# 1           u  6.228669e+03
# 2           g  2.628564e+04
# 3           r  9.671811e+03
# 4         run  2.174677e+01
# 5      camcol  8.341872e+00
# 6       field  1.025988e+01
# 7   specobjid  4.436092e+06
# 8    redshift  1.911457e+00
# 9       plate  9.955023e+04
# 10        mjd  3.223041e+06
# 11    fiberid  5.974122e+00

# %%
X.drop(columns=["u","g","specobjid", "plate", "mjd"], inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_=sc.fit_transform(X)
X_mod=pd.DataFrame(X_, columns=X.columns)

# %%
from sklearn.model_selection import train_test_split as split
X_train, X_test, y_train, y_test=split(X_mod,y, random_state=123, test_size=.2)

# %%
from sklearn.model_selection import train_test_split as split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error
model=[LogisticRegression(),GaussianNB(), SVC(), DecisionTreeClassifier(), RandomForestClassifier()]
for m in model:
    m.fit(X_train, y_train)
    m.score(X_train, y_train)
    y_pred=m.predict(X_test)
    print("for model:", m,"acc_score:", accuracy_score(y_test, y_pred))
    print("mse:",mean_absolute_error(y_test, y_pred))
    print("rmse:", np.sqrt(mean_squared_error(y_test, y_pred)))
    print("*********************************************")
    print()
    print()
# Out:
# for model: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False) acc_score: 0.971
# mse: 0.0475
# rmse: 0.2906888370749727
# *********************************************
#
#
# for model: GaussianNB(priors=None, var_smoothing=1e-09) acc_score: 0.987
# mse: 0.0165
# rmse: 0.1532970971675589
# *********************************************
#
#
# for model: SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False) acc_score: 0.963
# mse: 0.0645
# rmse: 0.3456877203488721
# *********************************************
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
knn.score(X_train, y_train)
y_pred=knn.predict(X_test)
print("for model:", knn,"acc_score:", accuracy_score(y_test, y_pred))
print("mse:",mean_absolute_error(y_test, y_pred))
print("rmse:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# for model: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform') acc_score: 0.8695
# mse: 0.249
# rmse: 0.697137002317335

# %%
print ("observation: GaussianNB is giving us higher degree of accuracy, so we will go forward with this model")
# Out:
# observation: GaussianNB is giving us higher degree of accuracy, so we will go forward with this model

# %%
from sklearn.model_selection import train_test_split as split
X_train, X_test, y_train, y_test=split(X_mod,y, random_state=123, test_size=.2)
final_model=GaussianNB()
final_model.fit(X_train, y_train)
final_model.score(X_train, y_train)
y_pred=final_model.predict(X_test)
print("for Model",final_model , "Accuracy Score:", accuracy_score(y_test,y_pred))
print("mse:",mean_absolute_error(y_test, y_pred))
print("rmse:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# for Model GaussianNB(priors=None, var_smoothing=1e-09) Accuracy Score: 0.987
# mse: 0.0165
# rmse: 0.1532970971675589

# %%
from sklearn.externals import joblib
joblib.dump(final_model, "skyserver_predictor.obj")
# Out:
# ['skyserver_predictor.obj']
