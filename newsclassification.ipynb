# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bs4 in ./.local/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/site-packages (from bs4) (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.0)
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.

# %%
# !pip install requests
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests) (2019.11.28)
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: html5lib in /usr/local/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/site-packages (from html5lib) (1.14.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/site-packages (from html5lib) (0.5.1)
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://timesofindia.indiatimes.com/2021/2/1/archivelist/year-2021,month-2,starttime-44228.cms")

# %%
htmlcontent1=page.content

# %%
soup=BeautifulSoup(htmlcontent1,"html.parser")

# %%
spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})

# %%
urls=[]
for i in spans:
    a=i.find_all("a")
    for j in a:
        urls.append(j.get("href"))

# %%
date=[]
author=[]
heading=[]
content=[]
verticle=[]
for link in urls:
    try: 
        page=requests.get("https://timesofindia.indiatimes.com/"+link)
        htmlcontent=page.content
        soup=BeautifulSoup(htmlcontent,"html.parser") 
        try:
            try:
                divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                for i in divs:
                    divs1=i.find_all("div", class_="as_heading")
                    for j in divs1:
                        head=j.find_all("h1")
                        heading.append(head[0].text)
                    try:
                        dat=i.find_all("div", {"data-plugin":"dateformat"})
                        date.append(dat[0].text[9:])
                    except:
                        date.append("NA")
                    try:
                        aut=i.find_all("a", class_="auth_detail")
                        author.append(aut[0].text)
                    except:
                        author.append("NA")
            except:
                heading.append("NA")
                date.append("NA")
                author.append("NA")
            for i in divs:
                con=i.find_all("div", class_="Normal")
                content.append(con[0].text)
                try:
                    vert=soup.find_all("span", {"itemprop":"name"})
                    verticle.append(vert[1].text)
                except:
                    verticle.append("NA")
        except:
            pass       
    except:
        pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44229.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44230.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44230.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44231.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44232.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44233.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44234.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44235.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44236.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44237.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44238.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44239.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44240.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44241.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44242.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44243.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44244.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44245.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44246.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44247.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44248.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44249.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44250.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44251.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44252.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44253.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44254.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44255.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
    page=requests.get("https://timesofindia.indiatimes.com/2021/2/28/archivelist/year-2021,month-2,starttime-44256.cms")
    htmlcontent1=page.content
    soup=BeautifulSoup(htmlcontent1,"html.parser")
    spans=soup.find_all("span", {"style":"font-family:arial ;font-size:12;color: #006699"})
    urls=[]
    for i in spans:
        a=i.find_all("a")
        for j in a:
            urls.append(j.get("href"))
    for link in urls:
        try: 
            page=requests.get("https://timesofindia.indiatimes.com/"+link)
            htmlcontent=page.content
            soup=BeautifulSoup(htmlcontent,"html.parser") 
            try:
                try:
                    divs=soup.find_all("div", class_="videos_player_md main_dpygrid")
                    for i in divs:
                        divs1=i.find_all("div", class_="as_heading")
                        for j in divs1:
                            head=j.find_all("h1")
                            heading.append(head[0].text)
                        try:
                            dat=i.find_all("div", {"data-plugin":"dateformat"})
                            date.append(dat[0].text[9:])
                        except:
                            date.append("NA")
                        try:
                            aut=i.find_all("a", class_="auth_detail")
                            author.append(aut[0].text)
                        except:
                            author.append("NA")
                except:
                    heading.append("NA")
                    date.append("NA")
                    author.append("NA")
                for i in divs:
                    con=i.find_all("div", class_="Normal")
                    content.append(con[0].text)
                    try:
                        vert=soup.find_all("span", {"itemprop":"name"})
                        verticle.append(vert[1].text)
                    except:
                        verticle.append("NA")
            except:
                pass       
        except:
            pass

# %%
len(heading),len(date),len(author), len(content), len(verticle)
# Out:
# (38, 38, 38, 38, 38)

# %%
import pandas as pd
news=pd.DataFrame()

# %%
news["Date"]=date
news["Author"]=author
news["Verticle"]=verticle
news["Heading"]=heading
news["Description"]=content

# %%
news.to_csv("News_Classification.csv")
